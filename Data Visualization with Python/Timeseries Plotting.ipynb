# %% [markdown]
# # Timeseries Plotting
#
# - A measure of unit change over time for any variable that is under observation. Forecasting can be done using historical data. It may have trend, seasonality and cyclic nature.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
# this lets plots to be plotted in same window
# %matplotlib inline
rcParams['figure.figsize'] = 10, 5 # 5 inch cross 4 inch figures
sb.set_style('whitegrid')

# %%
df = pd.read_csv('Superstore-Sales.csv', index_col = 'Order Date', parse_dates = True, encoding='cp1252')
df.head()
# Out:
#             Row ID  Order ID Order Priority  Order Quantity       Sales  \
# Order Date
# 2010-10-13       1         3            Low               6    261.5400
# 2012-10-01      49       293           High              49  10123.0200
# 2012-10-01      50       293           High              27    244.5700
# 2011-07-10      80       483           High              30   4965.7595
# 2010-08-28      85       515  Not Specified              19    394.2700
#
#             Discount       Ship Mode   Profit  Unit Price  Shipping Cost  \
# Order Date
# 2010-10-13      0.04     Regular Air  -213.25       38.94          35.00
# 2012-10-01      0.07  Delivery Truck   457.81      208.16          68.02
# 2012-10-01      0.01     Regular Air    46.71        8.69           2.99
# 2011-07-10      0.08     Regular Air  1198.97      195.99           3.99
# 2010-08-28      0.08     Regular Air    30.94       21.78           5.94
#
# ...

# %%
# Plotting order quantity
df['Order Quantity'].plot()
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
df2 = df.sample(n=100, random_state =25, axis =0)
plt.xlabel('Order Date')
plt.ylabel('Order Qty')
plt.title('Superstore-Sales')
df2['Order Quantity'].plot()
# Out:
# <AxesSubplot:title={'center':'Superstore-Sales'}, xlabel='Order Date', ylabel='Order Qty'>
